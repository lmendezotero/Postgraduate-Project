# %% [markdown]
# # Deep Learning Models

# %% [markdown]
# ## ** Notebook Content **

# %% [markdown]
# 1. Introduction
#
#
# 2. Data Preprocessing
#     - 2.1 Importing the required packages
#     - 2.2 Loading the dataset
#
#
# 3. Artificial Neural Netwoks Model

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# Explanation...

# %% [markdown]
# ## 2. Data Preprocessing

# %% [markdown]
# ### 2.1 Importing the required packages

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
# Out:
# Using TensorFlow backend.

# %%
#check the python version that we are using
print(sys.version)
# Out:
# 3.7.7 (default, May  6 2020, 11:45:54) [MSC v.1916 64 bit (AMD64)]

# %%
#check the tensorflow version that we are using
tf.__version__
# Out:
# '2.1.0'

# %% [markdown]
# ### 2.2 Importing the required packages

# %%
#loading the X_training set
X_train = pd.read_csv('Xtrain_baseline_model.csv')
X_train.head()
# Out:
#    MSZoning  LotFrontage  LotArea  Street  Utilities  LotConfig  Neighborhood  \
# 0         3         65.0     8450       1          0          4             5
# 1         3         80.0     9600       1          0          2            24
# 2         3         68.0    11250       1          0          4             5
# 3         3         60.0     9550       1          0          0             6
# 4         3         84.0    14260       1          0          2            15
#
#    Condition1  Condition2  HouseStyle  ...  KitchenQual_Ex  KitchenQual_Fa  \
# 0           2           2           5  ...               0               0
# 1           1           2           2  ...               0               0
# 2           2           2           5  ...               0               0
# 3           2           2           5  ...               0               0
# 4           2           2           5  ...               0               0
#
# ...

# %%
X_train.shape
# Out:
# (1324, 99)

# %%
#loading the X_training set
y_train = pd.read_pickle('y_training.pkl') 
y_train.head()
# Out:
# 0    208500.0
# 1    181500.0
# 2    223500.0
# 3    140000.0
# 4    250000.0
# Name: SalePrice, dtype: float64

# %%
y_train.shape
# Out:
# (1324,)

# %% [markdown]
# Explanation...

# %% [markdown]
# ## 3. Applying the Artificial Neural Netwok Model

# %% [markdown]
# Explanation...

# %% [markdown]
# ### 3.1 Building the ANN

# %% [markdown]
# #### 3.1.1 Initializing the ANN

# %%
#create the object for the ANN
ann = tf.keras.models.Sequential()

# %% [markdown]
# #### 3.1.2 Adding the input layer and the first hidden layer

# %%
#add a simple connected layer
ann.add(tf.keras.layers.Dense(units=500, activation='relu'))

# %% [markdown]
# #### 3.1.3 Adding the second hidden layer

# %%
#add a simple connected layer
ann.add(tf.keras.layers.Dense(units=500, activation='relu'))

# %% [markdown]
# #### 3.1.4 Adding the third hidden layer

# %%
#add a simple connected layer
ann.add(tf.keras.layers.Dense(units=500, activation='relu'))

# %% [markdown]
# #### 3.1.5 Adding the fourth hidden layer

# %%
#add a simple connected layer
ann.add(tf.keras.layers.Dense(units=500, activation='relu'))

# %% [markdown]
# #### 3.1.6 Adding the fifth hidden layer

# %%
#add a simple connected layer
ann.add(tf.keras.layers.Dense(units=500, activation='relu'))

# %% [markdown]
# #### 3.1.7 Adding the output layer

# %%
#add the output layer
ann.add(tf.keras.layers.Dense(units=1))

# %% [markdown]
# ### 3.2 Training the ANN

# %% [markdown]
# #### 3.2.1 Compiling the ANN

# %%
#compiling the ANN
ann.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %% [markdown]
# #### 3.2.2 Fitting the ANN

# %%
#training the ANN
ann.fit(X_train.values, y_train.values, batch_size = 32, epochs = 3000)
# Out:
# Train on 1324 samples
# Epoch 1/3000
# 1324/1324 [==============================] - 2s 1ms/sample - loss: 16632855274.7311
# Epoch 2/3000
# 1324/1324 [==============================] - 1s 565us/sample - loss: 3628344564.3988
# Epoch 3/3000
# 1324/1324 [==============================] - 1s 630us/sample - loss: 2413589493.9456
# Epoch 4/3000
# 1324/1324 [==============================] - 1s 633us/sample - loss: 2111281988.8338
# Epoch 5/3000
# 1324/1324 [==============================] - 1s 591us/sample - loss: 2017522916.9305
# Epoch 6/3000
# 1324/1324 [==============================] - 1s 606us/sample - loss: 1898638739.7221
# Epoch 7/3000
# 1324/1324 [==============================] - 1s 608us/sample - loss: 1860363455.8066
# Epoch 8/3000
# 1324/1324 [==============================] - 1s 602us/sample - loss: 1708648556.9547
# Epoch 9/3000
# 1324/1324 [==============================] - 1s 619us/sample - loss: 1511499776.0000
# Epoch 10/3000
# ...

# %% [markdown]
# ### 3.3 Predicting the results of the test set

# %%
#load the X_test set
X_test = pd.read_csv('Xtest_baseline_model.csv')
X_test.head()
# Out:
#    MSZoning  LotFrontage  LotArea  Street  Utilities  LotConfig  Neighborhood  \
# 0         2         80.0    11622       1          0          4            12
# 1         3         81.0    14267       1          0          0            12
# 2         3         74.0    13830       1          0          4             8
# 3         3         78.0     9978       1          0          4             8
# 4         3         43.0     5005       1          0          4            22
#
#    Condition1  Condition2  HouseStyle  ...  KitchenQual_Ex  KitchenQual_Fa  \
# 0           1           2           2  ...               0               0
# 1           2           2           2  ...               0               0
# 2           2           2           4  ...               0               0
# 3           2           2           4  ...               0               0
# 4           2           2           2  ...               0               0
#
# ...

# %%
#check the X_test set shape
X_test.shape
# Out:
# (1319, 99)

# %%
print(y_train)
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
#           ...
# 1455    175000.0
# 1456    210000.0
# 1457    266500.0
# 1458    142125.0
# 1459    147500.0
# Name: SalePrice, Length: 1324, dtype: float64

# %% [markdown]
# ### 3.4 Checking the performance of the model

# %%
#predict the test results of the train set
y_pred_1 = ann.predict(X_train)
np.set_printoptions(precision=2)
print(y_pred_1)
# Out:
# [[208852.06]
#  [180012.56]
#  [219871.25]
#  ...
#  [264679.22]
#  [143583.94]
#  [146732.44]]

# %%
print(y_train)
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
#           ...
# 1455    175000.0
# 1456    210000.0
# 1457    266500.0
# 1458    142125.0
# 1459    147500.0
# Name: SalePrice, Length: 1324, dtype: float64

# %%
import sklearn.metrics as metrics
print("R-squared =", metrics.r2_score(y_train, y_pred_1))
# Out:
# R-squared = 0.9991289341893231

# %%
print("MSE =", metrics.mean_squared_error(y_train, y_pred_1))
# Out:
# MSE = 4117652.13926449

# %%
#predict the test results of the test set
y_pred_2 = ann.predict(X_test)
np.set_printoptions(precision=2)
print(y_pred_2)
# Out:
# [[110239.82]
#  [156365.62]
#  [184430.78]
#  ...
#  [ 85875.36]
#  [174349.47]
#  [237139.75]]

# %%
y_pred_1_df = pd.DataFrame(y_pred_1)

# %%
y_pred_2_df = pd.DataFrame(y_pred_2)

# %%
#export to csv
y_pred_1_df.to_csv('y_pred_ann_train.csv', index=False)
y_pred_2_df.to_csv('y_pred_ann_test.csv', index=False)

# %% [markdown]
# In order to finally our analysis, we have collected the summarized the outcomes results and the errors of the prediction models (logistics regression, randome forest and artificial neural network).
#
# You can check the evidences in the following link:
#
# [Outcomes Models Summary](https://onedrive.live.com/edit.aspx?cid=ed1967779d009305&page=view&resid=ED1967779D009305!383&parId=ED1967779D009305!331&app=PowerPoint)
